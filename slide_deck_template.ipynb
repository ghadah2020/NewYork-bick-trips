# %% [markdown]
# #  Analyze New York Bike System
#
# ## By Ghadah
#
# ##Jan-2020

# %% [markdown]
# ## Investigation Overview
# I read the data and saved in data frame and cleened data and finally i visulized the data
# becuse I want to help the administration find answers to these questions
# Who is the most user type of using the system?
# Who is the most gender using the system?
# Who is the most age of user using the system?
# Which month the demand for bike increases?
# Any day of the week the usage is very high?
# Any hour of the day the demand for bikes rises?
# Which station is the most popular location for bike?.
#
# ## Dataset Overview
#
# This system was found to help people navigate the city and help them practice the sport of riding bikes, and it has gained wide popularity among people and a lot of companies have become investing in this field and it is certain that companies need to know what months of the year are most requested and to know the stations that start from the degrees and know the type of users And most of them use the system, their gender, and their ages from every city you want to invest in, to help the administration to take the right decisions in marketing and provide the appropriate number of grades to meet the needs of users. This project was worked on the data provided by the city NewyYork in the United States only  for the year 2019 from   January to November (11 months)
# the culmns in dataset is 15 culmns
# tripduration
# starttime
# stoptime
# start station id
# start station name
# start station latitude
# start station longitude
# end station id
# end station name
# end station latitude
# end station longitude
# bikeid
# usertype
# birth year
# gender

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import os
# %matplotlib inline
import seaborn as sns
import seaborn as sb
import csv
import datetime as dt
import calendar

# %%
# load in the dataset into a pandas dataframe
NewyYorkBike_clean = pd.read_csv('NewyYorkBike_clean.csv')
NewyYorkBike_clean.sample(5)
# Out:
#         tripduration                starttime                  stoptime  \
# 344427          1470  2019-11-16 16:32:55.360  2019-11-16 16:57:25.4000
# 265754           328  2019-09-17 07:07:25.754  2019-09-17 07:12:54.0540
# 260026           133  2019-09-13 07:44:09.957  2019-09-13 07:46:23.9290
# 77128            548  2019-04-27 07:01:31.396  2019-04-27 07:10:39.4000
# 115311           929  2019-05-24 09:26:54.284  2019-05-24 09:42:24.1200
#
#         start station id start station name  start station latitude  \
# 344427              3202       Newport PATH               40.727224
# 265754              3195            Sip Ave               40.730897
# 260026              3639         Harborside               40.719252
# 77128               3213     Van Vorst Park               40.718489
# 115311              3194    McGinley Square               40.725340
#
#         start station longitude  end station id            end station name  \
# 344427               -74.033759            3640              Journal Square
# 265754               -74.063913            3679                  Bergen Ave
# 260026               -74.034234            3792  Columbus Dr at Exchange Pl
# 77128                -74.047727            3202                Newport PATH
# 115311               -74.067622            3184                 Paulus Hook
#
#         end station latitude  ...    usertype  birth year  gender  Age  \
# 344427             40.733670  ...  Subscriber        1995  Female   25
# 265754             40.722104  ...  Subscriber        1964    Male   56
# 260026             40.716870  ...  Subscriber        1990    Male   30
# 77128              40.727224  ...  Subscriber        1987  Female   33
# 115311             40.714145  ...  Subscriber        1990    Male   30
#
#         Age_Grop  tripduration_minutes tripduration_hour  Month   weekday  \
# 344427  (16, 26]                    24                 0     11       NaN
# 265754  (46, 56]                     5                 0      9    Monday
# 260026  (26, 36]                     2                 0      9  Thursday
# 77128   (26, 36]                     9                 0      4    Friday
# 115311  (26, 36]                    15                 0      5    Friday
#
#         hour
# 344427    16
# 265754     7
# 260026     7
# 77128      7
# 115311     9
#
# [5 rows x 22 columns]

# %% [markdown]
# ## #  Analyze New York Bike System display kind of user using the Bike Trips system in bar chart .
#  After i see the bar chart the user from subscriber more than customer

# %%
#Display allmost kind of user using the Bike Trips system
# create the plot
plt.figure(figsize = [10, 5])
base_color = sb.color_palette()[0]
sb.countplot(data = NewyYorkBike_clean, x = 'usertype', color = base_color)

# add annotations
n_points = NewyYorkBike_clean.shape[0]
cat_counts = NewyYorkBike_clean['usertype'].value_counts()
locs, labels = plt.xticks() # get the current tick locations and labels

# loop through each pair of locations and labels
for loc, label in zip(locs, labels):

    # get the text property for the label to get the correct count
    count = cat_counts[label.get_text()]
    pct_string = '{:0.1f}%'.format(100*count/n_points)
    plt.title(' Display kind of user using the Bike Trips system');

# %% [markdown]
# ##   Analyze New York Bike System display the gender of user using the Bike Trips system in Pie chart .
# after i see the Pie chart the user Male more than the female

# %%
# code for the pie chart seen above
plt.figure(figsize = [10, 5])
sorted_counts = NewyYorkBike_clean['gender'].value_counts()
plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 100,
        counterclock = False);
plt.axis('square');
plt.title('Display the gender of user they using  Bike Trips system');

# %% [markdown]
# ## #  Display the higher months of using trips
#
# whin i see the bar chart i extract the high order trips in September month then the sales increase

# %%
plt.figure(figsize = [10, 5])
base_color = sb.color_palette()[0]
sb.countplot(data = NewyYorkBike_clean, x = 'Month', color = base_color)
plt.title('Display the higher months of users trips');

# %% [markdown]
# ##  Display Age group using the system

# %%
plt.figure(figsize = [10, 5])
base_color = sb.color_palette()[0]
sb.countplot(data = NewyYorkBike_clean, x = 'Age_Grop', color = base_color);
plt.title('Display Age group using the system');

# %% [markdown]
# # Display the trips in the weekday
#
# the bar in below  chart i extract the decrease the request of trips in Saturday Sunday.

# %%
plt.figure(figsize = [10, 5])
base_color = sb.color_palette()[0]
sb.countplot(data = NewyYorkBike_clean, y = 'weekday', color = base_color);
plt.title('Display the trips in the weekday');

# %% [markdown]
# # Analyze New York Bike System display the trips in the day hours
# the increase request of trips 8am and 6pm in day.

# %%
sb.distplot(NewyYorkBike_clean['hour'])
plt.ylabel('count user')
plt.title('trips in the day hours');

# %% [markdown]
# # Analyze New York Bike System Display the higher months of users trips duration
#
# when i see the chart i extract the most user they take long duration from age group (26-36 year) and the trip duration  increase in August and September.

# %%
# plot data
fig, ax = plt.subplots(figsize=(15,7))
# use unstack()
NewyYorkBike_clean.groupby(['Month','Age_Grop']).count()['tripduration'].unstack().plot(ax=ax);

# %% [markdown]
# # Analyze New York Bike System Display the station is the most popular location for bike
#
# when i see the  chart i extract  the most trips is start from station Grove st Path .

# %%
plt.figure(figsize = [10, 10])
base_color = sb.color_palette()[0]
type_order=NewyYorkBike_clean ['start station name'].value_counts().index
sb.countplot(data = NewyYorkBike_clean, y = 'start station name', color = base_color,order=type_order);
plt.xticks(rotation=90);

# %% [markdown]
# # Analyze New York Bike System Display the tripsduration for Gender

# %%
fig, ax = plt.subplots(figsize=(15,7))
ax = sb.barplot(data = NewyYorkBike_clean, x = 'usertype', y = 'tripduration', hue = 'gender')
ax.legend(loc = 7, ncol = 3, framealpha = 1, title = 'Gender')
plt.title('Display the tripsduration for Gender ');

# %% [markdown]
# # Analyze New York Bike System Display the tripsduration for user age

# %%
plt.figure(figsize=(7,6))
plt.scatter(NewyYorkBike_clean['tripduration_hour'], NewyYorkBike_clean['Age']) 
plt.title('User Age vs tripduration(hour)');
plt.xlabel('tripduration(hour)')
plt.ylabel('User Age')
plt.show()

# %% [markdown]
# # Analyze New York Bike System Display the tripsduration for Gender in each Month
#
#  customer trip duration more than subsecriber trip duration,Especially in February.

# %%
plt.figure(figsize = [10,5])
ax = sb.barplot(data = NewyYorkBike_clean, x = 'Month', y = 'tripduration', hue = 'usertype')
ax.legend(loc = 10, ncol = 10, framealpha = 3, title = 'usertype'); 
plt.title('Display the tripsduration for Gender in each Month ');

# %% [markdown]
# # summery
#
# In the system they have two type of user the  customer and subscriber .The most user using the system is the subscriber more than customer The high requst of trips in August and September months then sales trips is  increase(summer sesion). The trips request is decrease in Saturday Sunday (weekend).
#  the user request of trips increase  always day in  8-9am and 5-6pm in hour days.
# the Male user  using the trips more than the female using the system but the  female trip duration more than male  trip duration in bouthe customer or subscriber .
# The most users useing the system they have age between 26 to 36.
# The customer trip duration more than subsecriber trip duration,Especially in February .
# The most trips is start from station  Grove St Path station .

# %% [markdown]
# > Once you're ready to finish your presentation, check your output by using
# nbconvert to export the notebook and set up a server for the slides. From the
# terminal or command line, use the following expression:
# > > `jupyter nbconvert <file_name>.ipynb --to slides --post serve --template output_toggle`
#
# > This should open a tab in your web browser where you can scroll through your
# presentation. Sub-slides can be accessed by pressing 'down' when viewing its parent
# slide. Make sure you remove all of the quote-formatted guide notes like this one
# before you finish your presentation!
